# %%
import os 
from glob import glob
import nibabel as nib
import matplotlib.pyplot as plt

# %%
path= '/home/arshad/Downloads/amos22/amos22'
target_paths  = sorted(glob(os.path.join(path, "imagesTs","*.nii.gz")))[:25]

path_2 = '/home/arshad/Downloads/MedSeg/notebooks'
pred_paths  = sorted(glob(os.path.join(path_2, "results","*.nii.gz")))[:25]

# %%
target_paths[:5]
# Out:
# ['/home/arshad/Downloads/amos22/amos22/imagesTs/amos_0002.nii.gz',
#  '/home/arshad/Downloads/amos22/amos22/imagesTs/amos_0003.nii.gz',
#  '/home/arshad/Downloads/amos22/amos22/imagesTs/amos_0012.nii.gz',
#  '/home/arshad/Downloads/amos22/amos22/imagesTs/amos_0020.nii.gz',
#  '/home/arshad/Downloads/amos22/amos22/imagesTs/amos_0026.nii.gz']

# %%
pred_paths[:5]
# Out:
# ['/home/arshad/Downloads/MedSeg/notebooks/results/amos_0002.nii.gz',
#  '/home/arshad/Downloads/MedSeg/notebooks/results/amos_0003.nii.gz',
#  '/home/arshad/Downloads/MedSeg/notebooks/results/amos_0012.nii.gz',
#  '/home/arshad/Downloads/MedSeg/notebooks/results/amos_0020.nii.gz',
#  '/home/arshad/Downloads/MedSeg/notebooks/results/amos_0026.nii.gz']

# %%
plt.imshow(nib.load(target_paths[1]).get_fdata()[:,:,59])

# %%
plt.imshow(nib.load(pred_paths[1]).get_fdata()[:,:,59])
